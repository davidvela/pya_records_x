# %%
# Prolog - Auto Generated #
import os, uuid, matplotlib

matplotlib.use('Agg')

import matplotlib.pyplot
# %matplotlib notebook

import pandas

# %% [markdown]
# # Bike Sharing DS VIS

# %%
dataset = pandas.read_csv('./bike_sharing_daily.csv')

# %% [markdown]
# ## Seaborn

# %%
dataset.head()
# dataset.shape
# dataset["cnt"]
col = [ 'registered', 'hum' , 'atemp', 'casual', 'windspeed', 'temp'  ]
#        'instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit' ,'cnt']
dataset.columns
# dataset[col ]
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
# Original Script.
import seaborn as sns
import matplotlib.pyplot as plt
# matplotlib.pyplot.figure(figsize=(5.55555555555556,4.16666666666667))
matplotlib.pyplot.figure(figsize=(5.55555555555556,3.16666666666667))
# matplotlib.pyplot.show = lambda args=None,kw=None: matplotlib.pyplot.savefig(str(uuid.uuid1()))
matplotlib.pyplot.show = lambda args=None,kw=None: matplotlib.pyplot.savefig("./assets/"+str(uuid.uuid1()))

sns.swarmplot(x="season", y="cnt", data=dataset) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="554.9999917298557">

# %% [markdown]
# ## Altair Plots

# %%
import altair as alt
from vega_datasets import data

counties = alt.topo_feature(data.us_10m.url, 'counties')
unemp_data = data.unemployment.url

chart = alt.Chart(counties).mark_geoshape().encode(
    color='rate:Q'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(unemp_data, 'id', ['rate'])
).project(
    type='albersUsa'
).properties(
    width=500,
    height=300
)

chart
# chart.save('chart.png')
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# img=mpimg.imread('chart.png')
# imgplot = plt.imshow(img)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
data.unemployment.url
# Out:
# 'https://vega.github.io/vega-datasets/data/unemployment.tsv'

# %%
import altair as alt
from vega_datasets import data
# from selenium import webdriver
# driver = webdriver.Chrome(executable_path='/chromedriver_win32/chromedriver.exe')

cars = data.cars.url

chart = alt.Chart(cars).mark_point().encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    color='Origin:N',
)

chart
# chart.save('chart.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\velatida\appdata\local\continuum\miniconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# c:\users\velatida\appdata\local\continuum\miniconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %% [markdown]
# ## Correlation Plots

# %%
col = [ 'registered', 'hum' , 'atemp', 'casual', 'windspeed', 'temp'  ]
tmp_dataset =dataset[col ]

from pandas.plotting import scatter_matrix
scatter_matrix(tmp_dataset)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

col = [ 'registered', 'hum' ,'cnt', 'casual', 'atemp', 'windspeed', 'temp'  ]

tmp_dataset =dataset[col ]

sns.set(style="white")

# Compute the correlation matrix
corr = tmp_dataset.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1099.999983608723">

# %%
tmp_dataset
# Out:
#      registered       hum   cnt  casual     atemp  windspeed      temp
# 0           654  0.805833   985     331  0.363625   0.160446  0.344167
# 1           670  0.696087   801     131  0.353739   0.248539  0.363478
# 2          1229  0.437273  1349     120  0.189405   0.248309  0.196364
# 3          1454  0.590435  1562     108  0.212122   0.160296  0.200000
# 4          1518  0.436957  1600      82  0.229270   0.186900  0.226957
# 5          1518  0.518261  1606      88  0.233209   0.089565  0.204348
# 6          1362  0.498696  1510     148  0.208839   0.168726  0.196522
# 7           891  0.535833   959      68  0.162254   0.266804  0.165000
# 8           768  0.434167   822      54  0.116175   0.361950  0.138333
# 9          1280  0.482917  1321      41  0.150888   0.223267  0.150833
# 10         1220  0.686364  1263      43  0.191464   0.122132  0.169091
# 11         1137  0.599545  1162      25  0.160473   0.304627  0.172727
# ...

# %% [markdown]
# # Other

# %%
dataset2 = pandas.read_csv('bigml_59c28831336c6604c800002a.csv')

# %%
dataset2.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
dataset2.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...
