# %%
#!ls

import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
print("Hello")
# python -c 'import tensorflow as tf; print(tf.__version__)'
# Out:
# Hello

# %% [markdown]
# resources: <br/>
# https://www.dataquest.io/blog/excel-and-pandas/

# %% [markdown]
# # test1 -  read excel

# %%
file = "db.xlsx"
sheetno = 0 
# df = pd.read_excel(file, sheetname='db1')
while(1):
    try:
        df = pd.read_excel(file, sheetname=sheetno)#, index_col=0)
        sheetno = sheetno + 1
    except:
        break

print("Column headings:"); #print(df.columns)
# Out:
# Column headings:

# %%
xl = pd.ExcelFile(file)
xl.sheet_names  # see all sheet names
sheet_name = 1
df1 = xl.parse(sheet_name)  # read a specific sheet to DataFrame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-285bda4e5f5f> in <module>()
# ----> 1 xl = pd.ExcelFile(file)
#       2 xl.sheet_names  # see all sheet names
#       3 sheet_name = 1
#       4 df1 = xl.parse(sheet_name)  # read a specific sheet to DataFrame
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     392             self.book = xlrd.open_workbook(file_contents=data)
#     393         elif isinstance(self._io, compat.string_types):
# --> 394             self.book = xlrd.open_workbook(self._io)
#     395         else:
#     396             raise ValueError('Must explicitly set engine if not passing in'
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'db.xlsx'

# %%
df1.head()
# Out:
#      columnA  columnB columnC
# 0       rose      100     red
# 1  dandylion      200   white
# 2      daisy      300  yellow

# %%
df1.head()

# %% [markdown]
# ## test2 - loop excel

# %% [markdown]
# # test3 - build HTML/XML

# %%
# convert df1 to json -- read json in VUE app ...
